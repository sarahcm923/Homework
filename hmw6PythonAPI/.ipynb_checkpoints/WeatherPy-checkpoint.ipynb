# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 589

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# url for weather info
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
api_key = "065ea081e811b9d079ecfbbc46d38298"
outputs = []
index = 1
print("Begin Data Retrieval")
print("*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*")

# Build query URL
for city in cities:
    query_url = f"{url}appid={api_key}&q={city}&units={units}" 
    # Get weather data
    weather_response = requests.get(query_url).json()
        
    if weather_response['cod'] != "404":
        print (f"Processing Record #{index} | {city}") 
        #append weather data
        outputs.append(weather_response)
        index +=1
    
    else:
        print("City not found. Moving on...")
# Out:
# Begin Data Retrieval
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*
# Processing Record #1 | san luis
# Processing Record #2 | ribeira grande
# Processing Record #3 | mersing
# Processing Record #4 | mataura
# Processing Record #5 | castro
# Processing Record #6 | busselton
# Processing Record #7 | mar del plata
# Processing Record #8 | airai
# Processing Record #9 | hermanus
# Processing Record #10 | karratha
# Processing Record #11 | butaritari
# Processing Record #12 | nizwa
# Processing Record #13 | salym
# Processing Record #14 | jalu
# Processing Record #15 | bandarbeyla
# Processing Record #16 | nome
# Processing Record #17 | maniitsoq
# Processing Record #18 | new norfolk
# Processing Record #19 | la primavera
# Processing Record #20 | sochi
# Processing Record #21 | qaanaaq
# Processing Record #22 | roald
# Processing Record #23 | souillac
# Processing Record #24 | albany
# Processing Record #25 | luba
# Processing Record #26 | ambon
# Processing Record #27 | comodoro rivadavia
# Processing Record #28 | saskylakh
# Processing Record #29 | ahipara
# Processing Record #30 | ilheus
# Processing Record #31 | wilmington
# Processing Record #32 | ponta do sol
# Processing Record #33 | praia
# Processing Record #34 | leh
# Processing Record #35 | buchanan
# City not found. Moving on...
# Processing Record #36 | balsas
# Processing Record #37 | mizdah
# City not found. Moving on...
# Processing Record #38 | severo-kurilsk
# Processing Record #39 | northam
# Processing Record #40 | vaini
# Processing Record #41 | carora
# Processing Record #42 | methoni
# Processing Record #43 | hamilton
# Processing Record #44 | malabo
# Processing Record #45 | radchenko
# Processing Record #46 | port alfred
# Processing Record #47 | dikson
# Processing Record #48 | tekeli
# Processing Record #49 | avarua
# Processing Record #50 | tasiilaq
# Processing Record #51 | broken hill
# Processing Record #52 | fortuna
# Processing Record #53 | victoria
# Processing Record #54 | araouane
# Processing Record #55 | barahona
# Processing Record #56 | kodiak
# City not found. Moving on...
# Processing Record #57 | cidreira
# Processing Record #58 | rochegda
# Processing Record #59 | jamestown
# Processing Record #60 | east london
# Processing Record #61 | barrow
# Processing Record #62 | christchurch
# Processing Record #63 | zaraza
# Processing Record #64 | talnakh
# Processing Record #65 | basco
# Processing Record #66 | sur
# Processing Record #67 | port keats
# Processing Record #68 | college
# Processing Record #69 | villarrica
# Processing Record #70 | punta arenas
# Processing Record #71 | coquimbo
# Processing Record #72 | santiago de cao
# Processing Record #73 | monrovia
# Processing Record #74 | nanortalik
# Processing Record #75 | ushuaia
# Processing Record #76 | upernavik
# Processing Record #77 | nantucket
# Processing Record #78 | esperance
# Processing Record #79 | songea
# Processing Record #80 | bredasdorp
# Processing Record #81 | saint-philippe
# City not found. Moving on...
# Processing Record #82 | hilo
# Processing Record #83 | oranjestad
# Processing Record #84 | kavieng
# Processing Record #85 | hobart
# Processing Record #86 | cape town
# Processing Record #87 | williams lake
# Processing Record #88 | carnarvon
# Processing Record #89 | lebu
# Processing Record #90 | nyaunglebin
# Processing Record #91 | porto novo
# Processing Record #92 | te anau
# Processing Record #93 | flin flon
# Processing Record #94 | verkhnetulomskiy
# Processing Record #95 | bluff
# Processing Record #96 | kahului
# Processing Record #97 | geraldton
# Processing Record #98 | port hardy
# Processing Record #99 | tuktoyaktuk
# Processing Record #100 | siguiri
# Processing Record #101 | batagay-alyta
# Processing Record #102 | broome
# Processing Record #103 | nikolskoye
# Processing Record #104 | prado
# City not found. Moving on...
# Processing Record #105 | codrington
# Processing Record #106 | alihe
# Processing Record #107 | puerto ayora
# Processing Record #108 | pinawa
# Processing Record #109 | tallahassee
# City not found. Moving on...
# Processing Record #110 | manokwari
# Processing Record #111 | high level
# City not found. Moving on...
# Processing Record #112 | alyangula
# City not found. Moving on...
# Processing Record #113 | aasiaat
# City not found. Moving on...
# Processing Record #114 | port elizabeth
# Processing Record #115 | pevek
# Processing Record #116 | chokurdakh
# Processing Record #117 | chernyshevskiy
# Processing Record #118 | rikitea
# Processing Record #119 | norman wells
# Processing Record #120 | santa rosalia
# Processing Record #121 | dingle
# Processing Record #122 | kargasok
# Processing Record #123 | nola
# Processing Record #124 | iquique
# Processing Record #125 | los llanos de aridane
# Processing Record #126 | riposto
# Processing Record #127 | thompson
# Processing Record #128 | katsuura
# Processing Record #129 | sibolga
# Processing Record #130 | ozinki
# Processing Record #131 | lorengau
# Processing Record #132 | barra do garcas
# City not found. Moving on...
# Processing Record #133 | namibe
# Processing Record #134 | lodeynoye pole
# City not found. Moving on...
# Processing Record #135 | pisco
# Processing Record #136 | kapaa
# Processing Record #137 | peabiru
# Processing Record #138 | bethel
# City not found. Moving on...
# Processing Record #139 | tianpeng
# Processing Record #140 | cherskiy
# Processing Record #141 | soe
# Processing Record #142 | tura
# Processing Record #143 | berlevag
# Processing Record #144 | paamiut
# Processing Record #145 | yellowknife
# Processing Record #146 | moerai
# Processing Record #147 | kolondieba
# Processing Record #148 | barreirinhas
# Processing Record #149 | adrar
# Processing Record #150 | sitka
# Processing Record #151 | port pirie
# Processing Record #152 | shizilu
# Processing Record #153 | narsaq
# City not found. Moving on...
# City not found. Moving on...
# Processing Record #154 | fare
# Processing Record #155 | namatanai
# Processing Record #156 | longyearbyen
# Processing Record #157 | bathsheba
# Processing Record #158 | vila
# Processing Record #159 | faya
# Processing Record #160 | caravelas
# Processing Record #161 | cubuk
# Processing Record #162 | paros
# Processing Record #163 | flinders
# Processing Record #164 | sao filipe
# Processing Record #165 | gelemso
# Processing Record #166 | tazovskiy
# Processing Record #167 | ajaccio
# Processing Record #168 | cayenne
# Processing Record #169 | buraydah
# Processing Record #170 | trebnje
# Processing Record #171 | tarancon
# Processing Record #172 | xinxiang
# Processing Record #173 | kruisfontein
# Processing Record #174 | provideniya
# Processing Record #175 | beloha
# Processing Record #176 | lompoc
# Processing Record #177 | hadrut
# Processing Record #178 | faanui
# Processing Record #179 | moose factory
# Processing Record #180 | khatanga
# Processing Record #181 | baherden
# Processing Record #182 | bambous virieux
# Processing Record #183 | timmins
# City not found. Moving on...
# Processing Record #184 | tabat
# Processing Record #185 | henties bay
# Processing Record #186 | calama
# Processing Record #187 | pangnirtung
# City not found. Moving on...
# Processing Record #188 | iwanai
# Processing Record #189 | mahebourg
# Processing Record #190 | alofi
# Processing Record #191 | cairns
# Processing Record #192 | hithadhoo
# Processing Record #193 | sisimiut
# Processing Record #194 | clyde river
# Processing Record #195 | arraial do cabo
# City not found. Moving on...
# Processing Record #196 | constitucion
# Processing Record #197 | atuona
# Processing Record #198 | port blair
# Processing Record #199 | ondo
# Processing Record #200 | coihaique
# Processing Record #201 | petauke
# Processing Record #202 | turayf
# Processing Record #203 | kloulklubed
# Processing Record #204 | yeppoon
# Processing Record #205 | mocuba
# Processing Record #206 | padrauna
# Processing Record #207 | sistranda
# Processing Record #208 | la romana
# Processing Record #209 | salalah
# Processing Record #210 | portland
# Processing Record #211 | tiksi
# Processing Record #212 | yumen
# Processing Record #213 | renfrew
# Processing Record #214 | klaksvik
# Processing Record #215 | vardo
# Processing Record #216 | bubaque
# Processing Record #217 | glace bay
# City not found. Moving on...
# City not found. Moving on...
# Processing Record #218 | isangel
# Processing Record #219 | saint george
# Processing Record #220 | bushehr
# Processing Record #221 | luang prabang
# City not found. Moving on...
# Processing Record #222 | bima
# City not found. Moving on...
# Processing Record #223 | lavrentiya
# Processing Record #224 | katobu
# Processing Record #225 | matagami
# Processing Record #226 | senneterre
# Processing Record #227 | san policarpo
# Processing Record #228 | havelock
# Processing Record #229 | avera
# Processing Record #230 | aklavik
# Processing Record #231 | payson
# Processing Record #232 | svirstroy
# Processing Record #233 | acapulco
# Processing Record #234 | komsomolskiy
# Processing Record #235 | oistins
# Processing Record #236 | lucapa
# Processing Record #237 | alekseyevka
# Processing Record #238 | denpasar
# Processing Record #239 | mombetsu
# Processing Record #240 | bagdarin
# Processing Record #241 | sirsi
# Processing Record #242 | vestmannaeyjar
# Processing Record #243 | benito juarez
# Processing Record #244 | parnamirim
# Processing Record #245 | mount gambier
# Processing Record #246 | richards bay
# Processing Record #247 | sinnamary
# City not found. Moving on...
# City not found. Moving on...
# Processing Record #248 | ancud
# Processing Record #249 | at-bashi
# Processing Record #250 | turukhansk
# Processing Record #251 | warrington
# Processing Record #252 | heihe
# Processing Record #253 | dunedin
# Processing Record #254 | daltenganj
# Processing Record #255 | san pedro
# Processing Record #256 | yaqui
# Processing Record #257 | chuy
# Processing Record #258 | mae hong son
# Processing Record #259 | magadan
# Processing Record #260 | ayan
# Processing Record #261 | grande prairie
# Processing Record #262 | kalengwa
# Processing Record #263 | tambo
# Processing Record #264 | georgetown
# Processing Record #265 | naze
# Processing Record #266 | colon
# Processing Record #267 | rabo de peixe
# Processing Record #268 | ivankiv
# Processing Record #269 | hajnowka
# Processing Record #270 | altamira
# Processing Record #271 | saint anthony
# Processing Record #272 | tessalit
# Processing Record #273 | iqaluit
# Processing Record #274 | itarema
# Processing Record #275 | houlton
# Processing Record #276 | hami
# City not found. Moving on...
# Processing Record #277 | cabo san lucas
# Processing Record #278 | lanzhou
# Processing Record #279 | petropavlovsk-kamchatskiy
# Processing Record #280 | bunia
# Processing Record #281 | ust-omchug
# Processing Record #282 | honiara
# Processing Record #283 | kieta
# Processing Record #284 | jalingo
# Processing Record #285 | sao joao da barra
# Processing Record #286 | lasa
# Processing Record #287 | shelburne
# City not found. Moving on...
# Processing Record #288 | taoudenni
# Processing Record #289 | leningradskiy
# Processing Record #290 | gushikawa
# Processing Record #291 | san patricio
# City not found. Moving on...
# Processing Record #292 | hay river
# Processing Record #293 | hukuntsi
# Processing Record #294 | mujiayingzi
# Processing Record #295 | mnogovershinnyy
# Processing Record #296 | pangkalanbuun
# Processing Record #297 | syedove
# Processing Record #298 | novobirilyussy
# City not found. Moving on...
# Processing Record #299 | boli
# Processing Record #300 | axim
# Processing Record #301 | torbay
# Processing Record #302 | palmer
# Processing Record #303 | bar harbor
# Processing Record #304 | saint-louis
# City not found. Moving on...
# Processing Record #305 | aksarayskiy
# Processing Record #306 | kholodnyy
# Processing Record #307 | glens falls
# City not found. Moving on...
# Processing Record #308 | nong chik
# Processing Record #309 | agadez
# Processing Record #310 | opuwo
# Processing Record #311 | rundu
# Processing Record #312 | jambi
# City not found. Moving on...
# Processing Record #313 | lokoja
# Processing Record #314 | grindavik
# Processing Record #315 | toora-khem
# Processing Record #316 | zapolyarnyy
# Processing Record #317 | half moon bay
# City not found. Moving on...
# Processing Record #318 | thinadhoo
# Processing Record #319 | samarai
# City not found. Moving on...
# Processing Record #320 | guaymas
# Processing Record #321 | yefremov
# City not found. Moving on...
# Processing Record #322 | yakeshi
# Processing Record #323 | kutum
# Processing Record #324 | puerto quijarro
# Processing Record #325 | garowe
# City not found. Moving on...
# Processing Record #326 | tomatlan
# City not found. Moving on...
# Processing Record #327 | boguchany
# Processing Record #328 | arona
# Processing Record #329 | kedrovoye
# Processing Record #330 | bom jesus
# Processing Record #331 | bilibino
# Processing Record #332 | laguna
# Processing Record #333 | yar-sale
# Processing Record #334 | dayong
# City not found. Moving on...
# Processing Record #335 | mercedes
# Processing Record #336 | porosozero
# Processing Record #337 | mangrol
# Processing Record #338 | kaitangata
# Processing Record #339 | atambua
# Processing Record #340 | san carlos de bariloche
# Processing Record #341 | arman
# Processing Record #342 | inirida
# Processing Record #343 | rameswaram
# Processing Record #344 | vidim
# Processing Record #345 | nongan
# Processing Record #346 | pavelets
# Processing Record #347 | haverfordwest
# Processing Record #348 | yanam
# Processing Record #349 | pimentel
# Processing Record #350 | klyuchi
# Processing Record #351 | aswan
# Processing Record #352 | inhambane
# Processing Record #353 | simplicio mendes
# Processing Record #354 | talaya
# Processing Record #355 | ghugus
# Processing Record #356 | eatonton
# Processing Record #357 | huangchuan
# Processing Record #358 | havre-saint-pierre
# Processing Record #359 | dostpur
# Processing Record #360 | ginir
# Processing Record #361 | palma di montechiaro
# Processing Record #362 | lazaro cardenas
# Processing Record #363 | moron
# Processing Record #364 | honningsvag
# Processing Record #365 | yongan
# Processing Record #366 | pawai
# Processing Record #367 | general roca
# Processing Record #368 | voh
# Processing Record #369 | pingliang
# Processing Record #370 | qingyuan
# Processing Record #371 | seymchan
# Processing Record #372 | maningrida
# Processing Record #373 | kuvandyk
# Processing Record #374 | valle hermoso
# Processing Record #375 | sorland
# City not found. Moving on...
# Processing Record #376 | rokiskis
# Processing Record #377 | athabasca
# Processing Record #378 | viedma
# Processing Record #379 | kindersley
# Processing Record #380 | kondopoga
# Processing Record #381 | carutapera
# Processing Record #382 | bosansko grahovo
# Processing Record #383 | antropovo
# Processing Record #384 | westport
# Processing Record #385 | chicama
# Processing Record #386 | uravakonda
# Processing Record #387 | warora
# Processing Record #388 | elizabeth city
# Processing Record #389 | mayumba
# Processing Record #390 | pitimbu
# Processing Record #391 | daru
# Processing Record #392 | vila velha
# City not found. Moving on...
# Processing Record #393 | ardusat
# Processing Record #394 | saint-pierre
# Processing Record #395 | brae
# Processing Record #396 | michurinsk
# Processing Record #397 | zaysan
# Processing Record #398 | zhezkazgan
# Processing Record #399 | balaipungut
# City not found. Moving on...
# Processing Record #400 | sompeta
# Processing Record #401 | lagoa
# Processing Record #402 | huilong
# Processing Record #403 | chapais
# Processing Record #404 | tuatapere
# Processing Record #405 | san cristobal
# Processing Record #406 | quatre cocos
# Processing Record #407 | tautira
# Processing Record #408 | batsfjord
# Processing Record #409 | bonnyville
# City not found. Moving on...
# Processing Record #410 | fort morgan
# Processing Record #411 | abapo
# Processing Record #412 | huarmey
# Processing Record #413 | miri
# Processing Record #414 | sambava
# Processing Record #415 | bemidji
# Processing Record #416 | dickinson
# Processing Record #417 | teahupoo
# Processing Record #418 | houma
# Processing Record #419 | ngunguru
# Processing Record #420 | sayyan
# Processing Record #421 | serik
# Processing Record #422 | bang saphan
# Processing Record #423 | ixtapa
# Processing Record #424 | noumea
# City not found. Moving on...
# Processing Record #425 | chandauli
# Processing Record #426 | tashtagol
# Processing Record #427 | peniche
# Processing Record #428 | na klang
# Processing Record #429 | ostrovnoy
# Processing Record #430 | antofagasta
# Processing Record #431 | anadyr
# Processing Record #432 | mecca
# Processing Record #433 | walvis bay
# Processing Record #434 | cheyenne
# Processing Record #435 | metro
# Processing Record #436 | slave lake
# Processing Record #437 | lieto
# Processing Record #438 | la asuncion
# Processing Record #439 | kautokeino
# City not found. Moving on...
# Processing Record #440 | biswan
# Processing Record #441 | krasnokamensk
# Processing Record #442 | castlegar
# Processing Record #443 | camrose
# Processing Record #444 | moissala
# Processing Record #445 | vanersborg
# Processing Record #446 | nyagan
# Processing Record #447 | necochea
# City not found. Moving on...
# Processing Record #448 | fruitvale
# City not found. Moving on...
# Processing Record #449 | barcelona
# Processing Record #450 | byron bay
# Processing Record #451 | pitea
# Processing Record #452 | kem
# Processing Record #453 | waipawa
# Processing Record #454 | trairi
# Processing Record #455 | barabinsk
# Processing Record #456 | sao francisco do sul
# City not found. Moving on...
# Processing Record #457 | nemuro
# Processing Record #458 | port lincoln
# Processing Record #459 | igarka
# Processing Record #460 | evensk
# Processing Record #461 | santo amaro da imperatriz
# Processing Record #462 | saldanha
# Processing Record #463 | poum
# City not found. Moving on...
# Processing Record #464 | georgiyevka
# Processing Record #465 | forio
# Processing Record #466 | isla vista
# City not found. Moving on...
# Processing Record #467 | lobanovo
# Processing Record #468 | corbelia
# Processing Record #469 | pahrump
# Processing Record #470 | bandar-e lengeh
# City not found. Moving on...
# Processing Record #471 | ondangwa
# Processing Record #472 | boyolangu
# City not found. Moving on...
# Processing Record #473 | pak chong
# Processing Record #474 | haines junction
# Processing Record #475 | puerto escondido
# City not found. Moving on...
# Processing Record #476 | barmer
# Processing Record #477 | mackay
# Processing Record #478 | fayaoue
# Processing Record #479 | aden
# Processing Record #480 | nerang
# Processing Record #481 | omboue
# Processing Record #482 | ilulissat
# Processing Record #483 | kapit
# City not found. Moving on...
# Processing Record #484 | novokayakent
# Processing Record #485 | qianguo
# Processing Record #486 | roebourne
# Processing Record #487 | koslan
# Processing Record #488 | shimoda
# City not found. Moving on...
# Processing Record #489 | kosum phisai
# Processing Record #490 | guanica
# Processing Record #491 | santa rosa
# Processing Record #492 | muravlenko
# Processing Record #493 | mehamn
# Processing Record #494 | nuuk
# Processing Record #495 | bonavista
# Processing Record #496 | bose
# Processing Record #497 | svetlogorsk
# Processing Record #498 | nisia floresta
# Processing Record #499 | bairnsdale
# Processing Record #500 | leshukonskoye
# Processing Record #501 | colgong
# Processing Record #502 | mabaruma
# Processing Record #503 | kormilovka
# Processing Record #504 | tutoia
# Processing Record #505 | tefe
# Processing Record #506 | bereda
# Processing Record #507 | mountain home
# City not found. Moving on...
# Processing Record #508 | jardim
# Processing Record #509 | egvekinot
# Processing Record #510 | plettenberg bay
# Processing Record #511 | antalaha
# Processing Record #512 | lambarene
# Processing Record #513 | belmonte
# Processing Record #514 | quedlinburg
# Processing Record #515 | iskateley
# Processing Record #516 | darnah
# Processing Record #517 | uige
# Processing Record #518 | nha trang
# Processing Record #519 | neiafu
# Processing Record #520 | rincon
# Processing Record #521 | khani
# Processing Record #522 | ambulu
# Processing Record #523 | harrison
# Processing Record #524 | lata
# Processing Record #525 | katangli
# Processing Record #526 | touros
# Processing Record #527 | aubenas
# Processing Record #528 | kirakira
# City not found. Moving on...
# Processing Record #529 | usinsk
# City not found. Moving on...
# Processing Record #530 | fairbanks
# Processing Record #531 | cozma
# Processing Record #532 | rioja
# Processing Record #533 | inuvik
# Processing Record #534 | sioux lookout

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
from pprint import pprint
pprint(output)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 50.1, 'lon': -91.92},
#  'dt': 1536098340,
#  'id': 6148373,
#  'main': {'humidity': 100,
#           'pressure': 1013,
#           'temp': 68.94,
#           'temp_max': 71.6,
#           'temp_min': 66.2},
#  'name': 'Sioux Lookout',
#  'sys': {'country': 'CA',
#          'id': 3712,
#          'message': 0.0037,
#          'sunrise': 1536060513,
#          'sunset': 1536108186,
#          'type': 1},
#  'visibility': 19312,
#  'weather': [{'description': 'light intensity drizzle',
#               'icon': '09d',
#               'id': 300,
#               'main': 'Drizzle'}],
#  'wind': {'deg': 230, 'speed': 4.7}}

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
