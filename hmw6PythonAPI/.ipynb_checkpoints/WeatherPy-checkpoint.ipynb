# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# url for weather info
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
api_key = "065ea081e811b9d079ecfbbc46d38298"
outputs = []
data_pd = pd.DataFrame()
data_pd["Lat"] = ""
data_pd["Lng"] = ""
data_pd["Temp"] = ""
data_pd["Humidity"] = ""
data_pd["Cloudiness"] = ""
data_pd["Wind Speed"] = ""
i = 1

print("Begin Data Retrieval")
print("*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*")

# Build query URL
for city in cities:
    query_url = f"{url}appid={api_key}&q={city}&units={units}" 
    # Get weather data
    weather_response = requests.get(query_url).json()
        
    if weather_response['cod'] != "404":
        print (f"Processing Record #{i} | {city}") 
        #append weather data
        outputs.append(weather_response)
        
        lat = weather_response["coord"]["lat"]
        lng = weather_response["coord"]["lon"]
        temp = weather_response["main"]["temp"]
        humid = weather_response["main"]["humidity"]
        cloud = weather_response["clouds"]["all"]
        wind = weather_response["wind"]["speed"]
        data_pd.at[i,"Lat"]=lat
        data_pd.at[i,"Lng"]=lng
        data_pd.at[i,"Temp"]=temp
        data_pd.at[i,"Humidity"]=humid
        data_pd.at[i,"Cloudiness"]=cloud
        data_pd.at[i,"Wind Speed"]=wind

        i +=1

#data_pd.head()
    
    else:
        print("City not found. Moving on...")
# Out:
# Begin Data Retrieval
# *_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*_*
# Processing Record #1 | ushuaia
# Processing Record #2 | komsomolskiy
# Processing Record #3 | tezu
# Processing Record #4 | hobart
# Processing Record #5 | batouri
# Processing Record #6 | pevek
# Processing Record #7 | arraial do cabo
# Processing Record #8 | vaini
# Processing Record #9 | longyearbyen
# Processing Record #10 | puerto ayora
# Processing Record #11 | shimoda
# Processing Record #12 | hervey bay
# Processing Record #13 | worland
# Processing Record #14 | barrow
# Processing Record #15 | vestmannaeyjar
# Processing Record #16 | alice springs
# Processing Record #17 | albany
# Processing Record #18 | husavik
# City not found. Moving on...
# Processing Record #19 | mahebourg
# Processing Record #20 | chokurdakh
# City not found. Moving on...
# Processing Record #21 | cape town
# Processing Record #22 | kankan
# Processing Record #23 | sagarejo
# Processing Record #24 | bredasdorp
# Processing Record #25 | halifax
# Processing Record #26 | yatou
# Processing Record #27 | iracoubo
# City not found. Moving on...
# Processing Record #28 | buraydah
# Processing Record #29 | varhaug
# Processing Record #30 | atuona
# Processing Record #31 | limbang
# Processing Record #32 | castro
# Processing Record #33 | novovarshavka
# Processing Record #34 | qaqortoq
# Processing Record #35 | riyadh
# Processing Record #36 | sao filipe
# Processing Record #37 | cayenne
# Processing Record #38 | yellowknife
# Processing Record #39 | mataura
# City not found. Moving on...
# Processing Record #40 | rikitea
# Processing Record #41 | dikson
# Processing Record #42 | punta arenas
# Processing Record #43 | faanui
# City not found. Moving on...
# Processing Record #44 | bida
# Processing Record #45 | port hardy
# Processing Record #46 | iqaluit
# Processing Record #47 | severo-kurilsk
# Processing Record #48 | rudnichnyy
# Processing Record #49 | ponta do sol
# Processing Record #50 | honiara
# Processing Record #51 | sitka
# City not found. Moving on...
# Processing Record #52 | provideniya
# Processing Record #53 | larap
# Processing Record #54 | busselton
# City not found. Moving on...
# Processing Record #55 | hermanus
# Processing Record #56 | port hedland
# Processing Record #57 | kapaa
# Processing Record #58 | bluff
# Processing Record #59 | jamestown
# Processing Record #60 | hilo
# City not found. Moving on...
# Processing Record #61 | chitrakonda
# Processing Record #62 | sinnamary
# Processing Record #63 | luderitz
# Processing Record #64 | san patricio
# Processing Record #65 | yanam
# Processing Record #66 | omboue
# Processing Record #67 | okhotsk
# Processing Record #68 | new norfolk
# Processing Record #69 | zwedru
# Processing Record #70 | ilo
# Processing Record #71 | luebo
# Processing Record #72 | kaitangata
# Processing Record #73 | ghanzi
# Processing Record #74 | kaeo
# Processing Record #75 | butaritari
# Processing Record #76 | lima
# Processing Record #77 | ribeira grande
# City not found. Moving on...
# Processing Record #78 | ulcinj
# Processing Record #79 | chuy
# City not found. Moving on...
# Processing Record #80 | rorvik
# Processing Record #81 | jumla
# Processing Record #82 | saint-philippe
# Processing Record #83 | ulladulla
# Processing Record #84 | port alfred
# Processing Record #85 | stokmarknes
# Processing Record #86 | upernavik
# Processing Record #87 | ahipara
# Processing Record #88 | kahului
# Processing Record #89 | melbourne
# Processing Record #90 | tasiilaq
# Processing Record #91 | banda aceh
# Processing Record #92 | veinticinco de mayo
# Processing Record #93 | kruisfontein
# Processing Record #94 | kodiak
# Processing Record #95 | hay river
# Processing Record #96 | bonavista
# Processing Record #97 | tuktoyaktuk
# Processing Record #98 | saint george
# Processing Record #99 | nome
# Processing Record #100 | horodyshche
# Processing Record #101 | los llanos de aridane
# Processing Record #102 | grand baie
# Processing Record #103 | teguise
# Processing Record #104 | finschhafen
# City not found. Moving on...
# Processing Record #105 | mar del plata
# Processing Record #106 | killybegs
# Processing Record #107 | alyangula
# Processing Record #108 | catumbela
# Processing Record #109 | lisakovsk
# Processing Record #110 | agirish
# City not found. Moving on...
# Processing Record #111 | lodwar
# Processing Record #112 | kysyl-syr
# Processing Record #113 | alofi
# Processing Record #114 | portland
# Processing Record #115 | taikang
# Processing Record #116 | mehriz
# Processing Record #117 | norrtalje
# Processing Record #118 | pizarro
# Processing Record #119 | azogues
# Processing Record #120 | deputatskiy
# Processing Record #121 | nikolskoye
# Processing Record #122 | clyde river
# Processing Record #123 | carnarvon
# Processing Record #124 | kuytun
# Processing Record #125 | avarua
# City not found. Moving on...
# City not found. Moving on...
# Processing Record #126 | hirara
# City not found. Moving on...
# Processing Record #127 | hun
# Processing Record #128 | tura
# Processing Record #129 | khatanga
# Processing Record #130 | florianopolis
# Processing Record #131 | katsuura
# Processing Record #132 | jalingo
# City not found. Moving on...
# City not found. Moving on...
# Processing Record #133 | pacific grove
# Processing Record #134 | saldanha
# Processing Record #135 | dingle
# Processing Record #136 | birao
# Processing Record #137 | misratah
# City not found. Moving on...
# Processing Record #138 | bambous virieux
# Processing Record #139 | buluang
# Processing Record #140 | comodoro rivadavia
# Processing Record #141 | bawal
# Processing Record #142 | san quintin
# Processing Record #143 | yabelo
# Processing Record #144 | coihaique
# Processing Record #145 | jalu
# Processing Record #146 | klaksvik
# Processing Record #147 | isangel
# Processing Record #148 | cerrito
# Processing Record #149 | aquiraz
# Processing Record #150 | severo-yeniseyskiy
# Processing Record #151 | qaanaaq
# Processing Record #152 | victoria
# Processing Record #153 | katangli
# Processing Record #154 | chapais
# Processing Record #155 | narsaq
# Processing Record #156 | airai
# Processing Record #157 | namibe
# Processing Record #158 | fortuna
# Processing Record #159 | port augusta
# Processing Record #160 | grand-santi
# Processing Record #161 | ancud
# City not found. Moving on...
# City not found. Moving on...
# Processing Record #162 | ust-karsk
# Processing Record #163 | guiyang
# Processing Record #164 | baykit
# Processing Record #165 | solina
# Processing Record #166 | togur
# Processing Record #167 | saskylakh
# Processing Record #168 | cherskiy
# Processing Record #169 | huanren
# Processing Record #170 | kieta
# Processing Record #171 | winnemucca
# Processing Record #172 | rocha
# Processing Record #173 | kananga
# Processing Record #174 | khon kaen
# Processing Record #175 | nelson bay
# Processing Record #176 | aksu
# Processing Record #177 | boralday
# Processing Record #178 | waipawa
# Processing Record #179 | nioro
# Processing Record #180 | tiksi
# Processing Record #181 | xuanhua
# Processing Record #182 | boa vista
# Processing Record #183 | miraflores
# Processing Record #184 | bethel
# Processing Record #185 | moffat
# Processing Record #186 | lebu
# Processing Record #187 | arman
# Processing Record #188 | nizhnevartovsk
# Processing Record #189 | sironj
# Processing Record #190 | khani
# City not found. Moving on...
# City not found. Moving on...
# Processing Record #191 | dibrugarh
# City not found. Moving on...
# Processing Record #192 | chernyakhovsk
# Processing Record #193 | esperance
# Processing Record #194 | richards bay
# City not found. Moving on...
# Processing Record #195 | palafrugell
# Processing Record #196 | mehamn
# Processing Record #197 | hasaki
# Processing Record #198 | rodrigues alves
# Processing Record #199 | xining
# Processing Record #200 | torbay
# Processing Record #201 | oktyabrskoye
# Processing Record #202 | paamiut
# Processing Record #203 | mecca
# Processing Record #204 | manitouwadge
# City not found. Moving on...
# Processing Record #205 | chernyshevskiy
# Processing Record #206 | georgetown
# Processing Record #207 | taltal
# Processing Record #208 | sabang
# Processing Record #209 | vila velha
# Processing Record #210 | sumkino
# City not found. Moving on...
# Processing Record #211 | saint-louis
# Processing Record #212 | nikki
# City not found. Moving on...
# Processing Record #213 | rio claro
# City not found. Moving on...
# Processing Record #214 | lavrentiya
# Processing Record #215 | esso
# Processing Record #216 | sangar
# Processing Record #217 | caravelas
# Processing Record #218 | sabha
# Processing Record #219 | doda
# Processing Record #220 | east london
# Processing Record #221 | atambua
# Processing Record #222 | lompoc
# Processing Record #223 | pedernales
# City not found. Moving on...
# Processing Record #224 | port elizabeth
# Processing Record #225 | sangmelima
# City not found. Moving on...
# Processing Record #226 | hamilton
# Processing Record #227 | yumen
# City not found. Moving on...
# Processing Record #228 | amapa
# Processing Record #229 | mao
# Processing Record #230 | geeste
# Processing Record #231 | cidreira
# Processing Record #232 | ola
# Processing Record #233 | russell
# Processing Record #234 | san mateo del mar
# Processing Record #235 | codrington
# Processing Record #236 | jiwani
# Processing Record #237 | necochea
# Processing Record #238 | maiduguri
# Processing Record #239 | la palma
# Processing Record #240 | hagere hiywet
# Processing Record #241 | muros
# Processing Record #242 | juegang
# Processing Record #243 | suluq
# Processing Record #244 | lencois paulista
# City not found. Moving on...
# Processing Record #245 | bizhbulyak
# Processing Record #246 | matagami
# Processing Record #247 | erzin
# Processing Record #248 | markova
# Processing Record #249 | luanda
# Processing Record #250 | labytnangi
# Processing Record #251 | whitehorse
# Processing Record #252 | maceio
# Processing Record #253 | zalantun
# Processing Record #254 | partinico
# Processing Record #255 | tarma
# Processing Record #256 | inhambane
# Processing Record #257 | shingu
# Processing Record #258 | normandin
# City not found. Moving on...
# Processing Record #259 | torrijos
# Processing Record #260 | bambanglipuro
# Processing Record #261 | susehri
# Processing Record #262 | port keats
# Processing Record #263 | tuatapere
# Processing Record #264 | nacala
# Processing Record #265 | ilulissat
# Processing Record #266 | nishihara
# Processing Record #267 | valparaiso
# Processing Record #268 | westport
# Processing Record #269 | sorland
# Processing Record #270 | krasnorechenskiy
# Processing Record #271 | loa janan
# Processing Record #272 | cabo san lucas
# Processing Record #273 | kulhudhuffushi
# Processing Record #274 | pisco
# Processing Record #275 | tuy hoa
# Processing Record #276 | ensenada
# Processing Record #277 | otjiwarongo
# Processing Record #278 | kalianget
# Processing Record #279 | mount gambier
# Processing Record #280 | kavaratti
# Processing Record #281 | rovinj
# City not found. Moving on...
# Processing Record #282 | greystones
# Processing Record #283 | sao manuel
# Processing Record #284 | raudeberg
# Processing Record #285 | bathsheba
# Processing Record #286 | san pedro
# Processing Record #287 | areosa
# Processing Record #288 | ishigaki
# Processing Record #289 | aykhal
# Processing Record #290 | vao
# Processing Record #291 | souillac
# Processing Record #292 | huaiyin
# Processing Record #293 | geraldton
# Processing Record #294 | boma
# City not found. Moving on...
# Processing Record #295 | anloga
# Processing Record #296 | meulaboh
# Processing Record #297 | muzhi
# Processing Record #298 | constitucion
# Processing Record #299 | thompson
# Processing Record #300 | iberia
# Processing Record #301 | barabinsk
# Processing Record #302 | mamatid
# Processing Record #303 | vardo
# Processing Record #304 | hithadhoo
# Processing Record #305 | lana
# Processing Record #306 | shieli
# Processing Record #307 | arroio grande
# Processing Record #308 | shubarkuduk
# Processing Record #309 | rock springs
# City not found. Moving on...
# Processing Record #310 | vanimo
# Processing Record #311 | brae
# Processing Record #312 | kuryk
# Processing Record #313 | horta
# Processing Record #314 | kjollefjord
# Processing Record #315 | kudahuvadhoo
# Processing Record #316 | lipari
# Processing Record #317 | norman wells
# Processing Record #318 | mrakovo
# Processing Record #319 | miandrivazo
# Processing Record #320 | srednekolymsk
# Processing Record #321 | shitkino
# Processing Record #322 | hami
# Processing Record #323 | temirtau
# City not found. Moving on...
# Processing Record #324 | mucurapo
# Processing Record #325 | prince rupert
# Processing Record #326 | kathmandu
# Processing Record #327 | hofn
# Processing Record #328 | ukiah
# Processing Record #329 | bilibino
# Processing Record #330 | harindanga
# Processing Record #331 | rehoboth
# Processing Record #332 | vostok
# Processing Record #333 | lakeway
# Processing Record #334 | birin
# Processing Record #335 | baillif
# Processing Record #336 | sur
# Processing Record #337 | nanortalik
# Processing Record #338 | huesca
# Processing Record #339 | tiznit
# Processing Record #340 | flinders
# Processing Record #341 | noumea
# Processing Record #342 | manokwari
# Processing Record #343 | oregon
# Processing Record #344 | san cristobal
# Processing Record #345 | murgab
# Processing Record #346 | haines junction
# Processing Record #347 | lazaro cardenas
# Processing Record #348 | enshi
# Processing Record #349 | hobyo
# Processing Record #350 | egvekinot
# Processing Record #351 | selma
# Processing Record #352 | trapani
# Processing Record #353 | lashio
# Processing Record #354 | humaita
# City not found. Moving on...
# Processing Record #355 | zelenoborskiy
# Processing Record #356 | sabzevar
# City not found. Moving on...
# Processing Record #357 | ugoofaaru
# Processing Record #358 | grahamstown
# Processing Record #359 | sal rei
# Processing Record #360 | khandyga
# Processing Record #361 | auki
# Processing Record #362 | nouadhibou
# Processing Record #363 | zhigansk
# Processing Record #364 | atar
# Processing Record #365 | kloulklubed
# Processing Record #366 | taoudenni
# City not found. Moving on...
# Processing Record #367 | fairbanks
# Processing Record #368 | jizan
# Processing Record #369 | pervomayskiy
# Processing Record #370 | vysokogornyy
# Processing Record #371 | tougue
# City not found. Moving on...
# Processing Record #372 | seremban
# Processing Record #373 | leczna
# Processing Record #374 | mponela
# Processing Record #375 | sheridan
# Processing Record #376 | nouakchott
# Processing Record #377 | ostrovnoy
# Processing Record #378 | belmonte
# City not found. Moving on...
# Processing Record #379 | faya
# Processing Record #380 | gorin
# Processing Record #381 | half moon bay
# Processing Record #382 | tombouctou
# Processing Record #383 | salalah
# Processing Record #384 | hermiston
# Processing Record #385 | lorengau
# Processing Record #386 | hokitika
# Processing Record #387 | vangaindrano
# Processing Record #388 | leningradskiy
# Processing Record #389 | pedasi
# Processing Record #390 | tailai
# Processing Record #391 | quatre cocos
# Processing Record #392 | puerto del rosario
# Processing Record #393 | yulara
# Processing Record #394 | chicama
# Processing Record #395 | svetlogorsk
# Processing Record #396 | saint-pierre
# Processing Record #397 | tomatlan
# Processing Record #398 | matara
# Processing Record #399 | shentala
# City not found. Moving on...
# Processing Record #400 | goderich
# Processing Record #401 | illela
# Processing Record #402 | pasni
# Processing Record #403 | maraa
# Processing Record #404 | uniontown
# Processing Record #405 | gazojak
# Processing Record #406 | naze
# Processing Record #407 | toktogul
# Processing Record #408 | gat
# Processing Record #409 | maniitsoq
# Processing Record #410 | serdobsk
# Processing Record #411 | port blair
# Processing Record #412 | lata
# Processing Record #413 | changji
# City not found. Moving on...
# Processing Record #414 | puerto madryn
# City not found. Moving on...
# Processing Record #415 | praia
# Processing Record #416 | erenhot
# Processing Record #417 | yunhe
# Processing Record #418 | latung
# Processing Record #419 | margate
# Processing Record #420 | rexburg
# Processing Record #421 | mitu
# Processing Record #422 | tamandare
# Processing Record #423 | ocean city
# Processing Record #424 | torrox
# Processing Record #425 | mayumba
# Processing Record #426 | marienburg
# Processing Record #427 | college
# City not found. Moving on...
# Processing Record #428 | chimoio
# Processing Record #429 | lagoa
# Processing Record #430 | koulikoro
# Processing Record #431 | gravdal
# Processing Record #432 | kropotkin
# Processing Record #433 | dong hoi
# Processing Record #434 | port lincoln
# Processing Record #435 | bonfim
# Processing Record #436 | bondo
# Processing Record #437 | derzhavinsk
# Processing Record #438 | dossor
# City not found. Moving on...
# Processing Record #439 | severodvinsk
# Processing Record #440 | monaco-ville
# City not found. Moving on...
# Processing Record #441 | banamba
# Processing Record #442 | beringovskiy
# Processing Record #443 | morro bay
# Processing Record #444 | chateauroux
# Processing Record #445 | santiago del estero
# Processing Record #446 | padang
# Processing Record #447 | mazagao
# Processing Record #448 | port-gentil
# Processing Record #449 | victor harbor
# Processing Record #450 | pangody
# Processing Record #451 | katherine
# Processing Record #452 | pavlovsk
# Processing Record #453 | buala
# Processing Record #454 | ambilobe
# Processing Record #455 | tabou
# City not found. Moving on...
# City not found. Moving on...
# City not found. Moving on...
# Processing Record #456 | mazamari
# Processing Record #457 | melbu
# City not found. Moving on...
# Processing Record #458 | mastung
# Processing Record #459 | vila franca do campo
# Processing Record #460 | pilar
# Processing Record #461 | broken hill
# Processing Record #462 | sherpur
# Processing Record #463 | truth or consequences
# Processing Record #464 | xingcheng
# Processing Record #465 | mazatlan
# Processing Record #466 | marzuq
# Processing Record #467 | chulman
# Processing Record #468 | niamey
# Processing Record #469 | canico
# Processing Record #470 | ginda
# Processing Record #471 | kanniyakumari
# Processing Record #472 | port shepstone
# Processing Record #473 | sundsvall
# Processing Record #474 | hualmay
# Processing Record #475 | mtwara
# City not found. Moving on...
# Processing Record #476 | hambantota
# Processing Record #477 | ambanja
# Processing Record #478 | ardmore
# Processing Record #479 | batesville
# Processing Record #480 | acari
# Processing Record #481 | muroto
# Processing Record #482 | mnogovershinnyy
# City not found. Moving on...
# Processing Record #483 | ewa beach
# Processing Record #484 | gua musang
# Processing Record #485 | pangnirtung
# Processing Record #486 | skelleftea
# Processing Record #487 | torrington
# Processing Record #488 | cabedelo
# Processing Record #489 | kang
# Processing Record #490 | havoysund
# Processing Record #491 | pierre
# Processing Record #492 | whangarei
# Processing Record #493 | aklavik
# Processing Record #494 | pinkafeld
# Processing Record #495 | la rioja
# Processing Record #496 | the valley
# City not found. Moving on...
# Processing Record #497 | lubango
# Processing Record #498 | te anau
# Processing Record #499 | bestobe
# Processing Record #500 | kavieng
# Processing Record #501 | bhunya
# Processing Record #502 | birjand
# City not found. Moving on...
# Processing Record #503 | grafton
# Processing Record #504 | dondo
# Processing Record #505 | anadyr
# Processing Record #506 | narasannapeta
# City not found. Moving on...
# Processing Record #507 | jining
# Processing Record #508 | gladstone
# Processing Record #509 | dali
# Processing Record #510 | buta
# Processing Record #511 | havre-saint-pierre
# City not found. Moving on...
# Processing Record #512 | pandan
# City not found. Moving on...
# Processing Record #513 | ambato
# City not found. Moving on...
# Processing Record #514 | archidona
# Processing Record #515 | north bend
# Processing Record #516 | edd
# Processing Record #517 | kroya
# Processing Record #518 | kirkwood
# Processing Record #519 | nizhneudinsk
# City not found. Moving on...
# Processing Record #520 | leleasca
# Processing Record #521 | ndioum
# Processing Record #522 | vaitape
# Processing Record #523 | vestmanna
# Processing Record #524 | irtyshskiy
# Processing Record #525 | grand gaube
# Processing Record #526 | zile
# Processing Record #527 | monzon
# Processing Record #528 | poum
# Processing Record #529 | rabo de peixe
# Processing Record #530 | rio gallegos
# Processing Record #531 | avera
# Processing Record #532 | batagay
# Processing Record #533 | champagnole
# Processing Record #534 | bayangol
# Processing Record #535 | ambon
# Processing Record #536 | chongwe
# Processing Record #537 | bani
# Processing Record #538 | carbonia
# Processing Record #539 | berlevag
# Processing Record #540 | limuru
# Processing Record #541 | novoasbest
# Processing Record #542 | moussoro
# Processing Record #543 | troitskoye
# Processing Record #544 | talnakh
# Processing Record #545 | emerald

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data_pd.head()
# Out:
#      Lat     Lng   Temp Humidity Cloudiness Wind Speed
# 1 -54.81  -68.31  50.79       40          0       20.8
# 2  67.55   63.78  41.26       91         92      14.65
# 3  27.93   96.16  65.47       94         92        1.9
# 4 -42.88  147.33   48.2       81         20       9.17
# 5   4.44   14.36  76.09       98         64       4.25

# %%
#export to csv
data_pd.to_csv("weatherpy.csv", index=False)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
print(temp)
# Out:
# 58.72

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
